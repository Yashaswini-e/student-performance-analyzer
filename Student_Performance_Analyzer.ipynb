# %%
students = []

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter student name: ")
    marks = int(input("Enter marks: "))
    students.append((name, marks))

print(students)
# Out:
# Enter number of students: 4
# Enter student name: Yashu
# Enter marks: 89
# Enter student name: Jahnavi
# Enter marks: 67
# Enter student name: Manasa
# Enter marks: 78
# Enter student name: Pritika
# Enter marks: 45
# [('Yashu', 89), ('Jahnavi', 67), ('Manasa', 78), ('Pritika', 45)]

# %%
total = 0

for student in students:
    total += student[1]

average = total / n
print("Class Average:", average)
# Out:
# Class Average: 69.75

# %%
for student in students:
    name, marks = student

    if marks >= 75:
        grade = "A"
    elif marks >= 60:
        grade = "B"
    elif marks >= 40:
        grade = "C"
    else:
        grade = "F"

    status = "Pass" if marks >= 40 else "Fail"

    print(name, "- Marks:", marks, "| Grade:", grade, "| Status:", status)
# Out:
# Yashu - Marks: 89 | Grade: A | Status: Pass
# Jahnavi - Marks: 67 | Grade: B | Status: Pass
# Manasa - Marks: 78 | Grade: A | Status: Pass
# Pritika - Marks: 45 | Grade: C | Status: Pass

# %%
topper = max(students, key=lambda x: x[1])
print("Topper:", topper[0], "with", topper[1], "marks")
# Out:
# Topper: Yashu with 89 marks

# %% [markdown]
# Project 2 Student Performance Analyzer
#
# • Built a Python program to store student names and marks using lists and tuples.
#
# • Implemented logic to calculate class average and determine grades.
#
# • Used conditional statements to identify pass/fail status.
#
# • Identified top-performing student using built-in functions.
